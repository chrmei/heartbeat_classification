# %% [markdown]
# # B 02 Lazy Classifier: PTB Dataset

# %% [markdown]
# ## 1. Imports

# %%
import numpy as np
import pandas as pd
from lazypredict.Supervised import LazyClassifier

# %%
print("\n" + "="*80)
print("Evaluating MIT-trained 5-class XGBoost mapped to binary on full PTB (train+val)")
print("="*80)

# Load PTB split (both train and test)
# validation is left out to compare 
ptb_dir = "/home/christianm/Projects/Repos/heartbeat_classification/data/processed/ptb"

X_ptb_train_sm = pd.read_csv(f"{ptb_dir}/X_ptb_train_sm.csv").values
y_ptb_train_sm = pd.read_csv(f"{ptb_dir}/y_ptb_train_sm.csv").iloc[:, 0].values.astype(int)
X_ptb_test = pd.read_csv(f"{ptb_dir}/X_ptb_test.csv").values
y_ptb_test = pd.read_csv(f"{ptb_dir}/y_ptb_test.csv").iloc[:, 0].values.astype(int)
X_ptb_val = pd.read_csv(f"{ptb_dir}/X_ptb_val.csv").values
y_ptb_val = pd.read_csv(f"{ptb_dir}/y_ptb_val.csv").iloc[:, 0].values.astype(int)

print("PTB dataset")
print(f"\tTraining size: {X_ptb_train_sm.shape}, {y_ptb_train_sm.shape}")
print(f"\tTraining SMOTE size: {X_ptb_train_sm.shape}, {y_ptb_train_sm.shape}")
print(f"\tTest Size: {X_ptb_test.shape}, {y_ptb_test.shape}")
# print(f"\tVal Size: {X_ptb_val.shape}, {y_ptb_val.shape}")
# Out:
# ================================================================================
# Evaluating MIT-trained 5-class XGBoost mapped to binary on full PTB (train+val)
# ================================================================================
# PTB dataset
# 	Training size: (13438, 187), (13438,)
# 	Training SMOTE size: (13438, 187), (13438,)
# 	Test Size: (2909, 187), (2909,)

# %%
#LazyClassifier on PTB SMOTE training data, test data
clf = LazyClassifier(verbose=1,ignore_warnings=True, custom_metric=None)

models,predictions = clf.fit(X_ptb_train_sm, X_ptb_test, y_ptb_train_sm, y_ptb_test)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# {'Model': 'AdaBoostClassifier', 'Accuracy': 0.7954623581986937, 'Balanced Accuracy': 0.8184384013185002, 'ROC AUC': 0.8184384013185002, 'F1 Score': 0.804798913632478, 'Time taken': 10.613378047943115}
# {'Model': 'BaggingClassifier', 'Accuracy': 0.9432794774836714, 'Balanced Accuracy': 0.9458961681087763, 'ROC AUC': 0.9458961681087763, 'F1 Score': 0.9441267104960197, 'Time taken': 19.013993501663208}
# {'Model': 'BernoulliNB', 'Accuracy': 0.6132691646613957, 'Balanced Accuracy': 0.6432341515098005, 'ROC AUC': 0.6432341515098005, 'F1 Score': 0.6332544740242653, 'Time taken': 0.1459810733795166}
# {'Model': 'CalibratedClassifierCV', 'Accuracy': 0.7848057751804743, 'Balanced Accuracy': 0.7859806345282241, 'ROC AUC': 0.7859806345282241, 'F1 Score': 0.7930685368623994, 'Time taken': 9.205572605133057}
# {'Model': 'DecisionTreeClassifier', 'Accuracy': 0.9082158817463045, 'Balanced Accuracy': 0.8938739772794161, 'ROC AUC': 0.893873977279416, 'F1 Score': 0.9089292288858235, 'Time taken': 2.7145771980285645}
# {'Model': 'DummyClassifier', 'Accuracy': 0.27810244070127194, 'Balanced Accuracy': 0.5, 'ROC AUC': 0.5, 'F1 Score': 0.1210246769915702, 'Time taken': 0.04613375663757324}
# {'Model': 'ExtraTreeClassifier', 'Accuracy': 0.8899965623925747, 'Balanced Accuracy': 0.8812549296603684, 'ROC AUC': 0.8812549296603683, 'F1 Score': 0.8917905821669935, 'Time taken': 0.06154799461364746}
# {'Model': 'ExtraTreesClassifier', 'Accuracy': 0.9766242695084222, 'Balanced Accuracy': 0.969371357937489, 'ROC AUC': 0.969371357937489, 'F1 Score': 0.9765884134355075, 'Time taken': 1.5879409313201904}
# {'Model': 'GaussianNB', 'Accuracy': 0.6094877964936404, 'Balanced Accuracy': 0.67671051857084, 'ROC AUC': 0.67671051857084, 'F1 Score': 0.6270206542106032, 'Time taken': 0.06651139259338379}
# {'Model': 'KNeighborsClassifier', 'Accuracy': 0.8965280165005156, 'Balanced Accuracy': 0.9138951674612985, 'ROC AUC': 0.9138951674612985, 'F1 Score': 0.8999156781599444, 'Time taken': 0.22012615203857422}
# {'Model': 'LabelPropagation', 'Accuracy': 0.8662770711584737, 'Balanced Accuracy': 0.8902831243745952, 'ROC AUC': 0.8902831243745952, 'F1 Score': 0.8715809143710774, 'Time taken': 4.523557186126709}
# {'Model': 'LabelSpreading', 'Accuracy': 0.8662770711584737, 'Balanced Accuracy': 0.8902831243745952, 'ROC AUC': 0.8902831243745952, 'F1 Score': 0.8715809143710774, 'Time taken': 9.746297359466553}
# {'Model': 'LinearDiscriminantAnalysis', 'Accuracy': 0.7548985905809557, 'Balanced Accuracy': 0.7804644181529226, 'ROC AUC': 0.7804644181529226, 'F1 Score': 0.7668694603310859, 'Time taken': 0.3889009952545166}
# {'Model': 'LinearSVC', 'Accuracy': 0.7844620144379512, 'Balanced Accuracy': 0.789542056624875, 'ROC AUC': 0.789542056624875, 'F1 Score': 0.7931159533983335, 'Time taken': 2.297393798828125}
# {'Model': 'LogisticRegression', 'Accuracy': 0.7851495359229976, 'Balanced Accuracy': 0.7881184884336925, 'ROC AUC': 0.7881184884336925, 'F1 Score': 0.7935640755392767, 'Time taken': 0.9564211368560791}
# {'Model': 'NearestCentroid', 'Accuracy': 0.5864558267445857, 'Balanced Accuracy': 0.6326417093413386, 'ROC AUC': 0.6326417093413386, 'F1 Score': 0.6066020492863624, 'Time taken': 0.08443975448608398}
# {'Model': 'NuSVC', 'Accuracy': 0.8315572361636301, 'Balanced Accuracy': 0.8590164223909589, 'ROC AUC': 0.8590164223909589, 'F1 Score': 0.8390115295656865, 'Time taken': 21.30358338356018}
# {'Model': 'PassiveAggressiveClassifier', 'Accuracy': 0.7067720866277071, 'Balanced Accuracy': 0.6829192418623815, 'ROC AUC': 0.6829192418623816, 'F1 Score': 0.7171996363816626, 'Time taken': 0.1383819580078125}
# {'Model': 'Perceptron', 'Accuracy': 0.763836369886559, 'Balanced Accuracy': 0.7509394313967861, 'ROC AUC': 0.7509394313967863, 'F1 Score': 0.7718611656183826, 'Time taken': 0.11139369010925293}
# {'Model': 'QuadraticDiscriminantAnalysis', 'Accuracy': 0.7700240632519766, 'Balanced Accuracy': 0.792840367296486, 'ROC AUC': 0.792840367296486, 'F1 Score': 0.7809115873501906, 'Time taken': 0.24422788619995117}
# {'Model': 'RandomForestClassifier', 'Accuracy': 0.9700928154004813, 'Balanced Accuracy': 0.965227500147154, 'ROC AUC': 0.9652275001471541, 'F1 Score': 0.9701655754214529, 'Time taken': 10.976329803466797}
# {'Model': 'RidgeClassifier', 'Accuracy': 0.755586112066002, 'Balanced Accuracy': 0.780940608629113, 'ROC AUC': 0.7809406086291131, 'F1 Score': 0.7675039306776429, 'Time taken': 0.08239507675170898}
# {'Model': 'RidgeClassifierCV', 'Accuracy': 0.755586112066002, 'Balanced Accuracy': 0.7813205603625876, 'ROC AUC': 0.7813205603625876, 'F1 Score': 0.767523402938853, 'Time taken': 0.2655160427093506}
# {'Model': 'SGDClassifier', 'Accuracy': 0.7848057751804743, 'Balanced Accuracy': 0.7749620342574608, 'ROC AUC': 0.7749620342574607, 'F1 Score': 0.7918738295146405, 'Time taken': 0.5424675941467285}
# {'Model': 'SVC', 'Accuracy': 0.912341010656583, 'Balanced Accuracy': 0.9199081758785096, 'ROC AUC': 0.9199081758785096, 'F1 Score': 0.9144705142952293, 'Time taken': 9.131274223327637}
# {'Model': 'XGBClassifier', 'Accuracy': 0.9762805087658989, 'Balanced Accuracy': 0.9717929248337159, 'ROC AUC': 0.9717929248337159, 'F1 Score': 0.9763117976594339, 'Time taken': 5.154160022735596}
# [LightGBM] [Info] Number of positive: 6719, number of negative: 6719
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003971 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 43403
# [LightGBM] [Info] Number of data points in the train set: 13438, number of used features: 186
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# {'Model': 'LGBMClassifier', 'Accuracy': 0.9735304228257133, 'Balanced Accuracy': 0.9702681146624286, 'ROC AUC': 0.9702681146624286, 'F1 Score': 0.9736142451562972, 'Time taken': 0.499439001083374}

# %%
#results for different models sorted by accuracy
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# ExtraTreesClassifier               0.98               0.97     0.97      0.98
# RandomForestClassifier             0.97               0.97     0.97      0.97
# BaggingClassifier                  0.94               0.95     0.95      0.94
# SVC                                0.91               0.92     0.92      0.91
# KNeighborsClassifier               0.90               0.91     0.91      0.90
# DecisionTreeClassifier             0.91               0.89     0.89      0.91
# LabelPropagation                   0.87               0.89     0.89      0.87
# LabelSpreading                     0.87               0.89     0.89      0.87
# ExtraTreeClassifier                0.89               0.88     0.88      0.89
# NuSVC                              0.83               0.86     0.86      0.84
# AdaBoostClassifier                 0.80               0.82     0.82      0.80
# QuadraticDiscriminantAnalysis      0.77               0.79     0.79      0.78
# LinearSVC                          0.78               0.79     0.79      0.79
# LogisticRegression                 0.79               0.79     0.79      0.79
# CalibratedClassifierCV             0.78               0.79     0.79      0.79
# RidgeClassifierCV                  0.76               0.78     0.78      0.77
# RidgeClassifier                    0.76               0.78     0.78      0.77
# LinearDiscriminantAnalysis         0.75               0.78     0.78      0.77
# SGDClassifier                      0.78               0.77     0.77      0.79
# Perceptron                         0.76               0.75     0.75      0.77
# PassiveAggressiveClassifier        0.71               0.68     0.68      0.72
# GaussianNB                         0.61               0.68     0.68      0.63
# BernoulliNB                        0.61               0.64     0.64      0.63
# NearestCentroid                    0.59               0.63     0.63      0.61
# DummyClassifier                    0.28               0.50     0.50      0.12
#
#                                Time Taken
# Model
# XGBClassifier                        5.15
# LGBMClassifier                       0.50
# ExtraTreesClassifier                 1.59
# RandomForestClassifier              10.98
# BaggingClassifier                   19.01
# SVC                                  9.13
# KNeighborsClassifier                 0.22
# DecisionTreeClassifier               2.71
# LabelPropagation                     4.52
# LabelSpreading                       9.75
# ExtraTreeClassifier                  0.06
# NuSVC                               21.30
# AdaBoostClassifier                  10.61
# QuadraticDiscriminantAnalysis        0.24
# LinearSVC                            2.30
# LogisticRegression                   0.96
# CalibratedClassifierCV               9.21
# RidgeClassifierCV                    0.27
# RidgeClassifier                      0.08
# LinearDiscriminantAnalysis           0.39
# SGDClassifier                        0.54
# Perceptron                           0.11
# PassiveAggressiveClassifier          0.14
# GaussianNB                           0.07
# BernoulliNB                          0.15
# NearestCentroid                      0.08
# DummyClassifier                      0.05

# %%
#models sorted by F1 score instead of accuracy
print(models.sort_values(by='F1 Score', ascending=False))
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.98               0.97     0.97      0.98
# XGBClassifier                      0.98               0.97     0.97      0.98
# LGBMClassifier                     0.97               0.97     0.97      0.97
# RandomForestClassifier             0.97               0.97     0.97      0.97
# BaggingClassifier                  0.94               0.95     0.95      0.94
# SVC                                0.91               0.92     0.92      0.91
# DecisionTreeClassifier             0.91               0.89     0.89      0.91
# KNeighborsClassifier               0.90               0.91     0.91      0.90
# ExtraTreeClassifier                0.89               0.88     0.88      0.89
# LabelPropagation                   0.87               0.89     0.89      0.87
# LabelSpreading                     0.87               0.89     0.89      0.87
# NuSVC                              0.83               0.86     0.86      0.84
# AdaBoostClassifier                 0.80               0.82     0.82      0.80
# LogisticRegression                 0.79               0.79     0.79      0.79
# LinearSVC                          0.78               0.79     0.79      0.79
# CalibratedClassifierCV             0.78               0.79     0.79      0.79
# SGDClassifier                      0.78               0.77     0.77      0.79
# QuadraticDiscriminantAnalysis      0.77               0.79     0.79      0.78
# Perceptron                         0.76               0.75     0.75      0.77
# RidgeClassifierCV                  0.76               0.78     0.78      0.77
# RidgeClassifier                    0.76               0.78     0.78      0.77
# LinearDiscriminantAnalysis         0.75               0.78     0.78      0.77
# PassiveAggressiveClassifier        0.71               0.68     0.68      0.72
# BernoulliNB                        0.61               0.64     0.64      0.63
# GaussianNB                         0.61               0.68     0.68      0.63
# NearestCentroid                    0.59               0.63     0.63      0.61
# DummyClassifier                    0.28               0.50     0.50      0.12
#
#                                Time Taken
# Model
# ExtraTreesClassifier                 1.59
# XGBClassifier                        5.15
# LGBMClassifier                       0.50
# RandomForestClassifier              10.98
# BaggingClassifier                   19.01
# SVC                                  9.13
# DecisionTreeClassifier               2.71
# KNeighborsClassifier                 0.22
# ExtraTreeClassifier                  0.06
# LabelPropagation                     4.52
# LabelSpreading                       9.75
# NuSVC                               21.30
# AdaBoostClassifier                  10.61
# LogisticRegression                   0.96
# LinearSVC                            2.30
# CalibratedClassifierCV               9.21
# SGDClassifier                        0.54
# QuadraticDiscriminantAnalysis        0.24
# Perceptron                           0.11
# RidgeClassifierCV                    0.27
# RidgeClassifier                      0.08
# LinearDiscriminantAnalysis           0.39
# PassiveAggressiveClassifier          0.14
# BernoulliNB                          0.15
# GaussianNB                           0.07
# NearestCentroid                      0.08
# DummyClassifier                      0.05
