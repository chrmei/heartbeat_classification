# %% [markdown]
# # CNN Model - 2018 Paper (Kachuee, Fazeli, Sarrafzadeh): CNN8
#
# - with added dropout
# - and Batch Normalization
# - and one removed last fully connected layer

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization, ReLU, Add, MaxPooling1D, 
    Dropout, Flatten, Dense
)
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay

from sklearn.metrics import (
    accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report
)
from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE, RandomOverSampler

from pathlib import Path
import re 

import pickle
import os
import json 
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
print(tf.config.list_physical_devices('GPU'))  # should show []
from contextlib import redirect_stdout

from src.visualization.visualization import plot_training_history
# Out:
# []

# %%
SAMPLING_METHOD = "SMOTE"
REMOVE_OUTLIERS = False
model_name = "cnn8_sm"
OUTPUT_PATH = "src/models/CNN/"
results_csv = "reports/03_model_testing_results/05_CNN_model_comparison.csv"
EPOCHS = 50

#import MIT data
df_mitbih_test = pd.read_csv('data/original/mitbih_test.csv', header = None)

X_train = pd.read_csv('data/processed/mitbih/X_train.csv')
y_train = pd.read_csv('data/processed/mitbih/y_train.csv')
y_train = y_train['187']

X_train_sm = pd.read_csv('data/processed/mitbih/X_train_sm.csv')
y_train_sm = pd.read_csv('data/processed/mitbih/y_train_sm.csv')
y_train_sm = y_train_sm['187']

X_val = pd.read_csv('data/processed/mitbih/X_val.csv')
y_val = pd.read_csv('data/processed/mitbih/y_val.csv')
y_val = y_val['187']

X_test = df_mitbih_test.drop(187, axis = 1)
y_test = df_mitbih_test[187]


# Reshape the data for 1D CNN
X_train_sm_cnn = np.expand_dims(X_train_sm, axis=2)
X_val_cnn = np.expand_dims(X_val, axis=2)
X_test_cnn = np.expand_dims(X_test, axis=2) 

display(X_train_sm_cnn.shape)
display(X_val_cnn.shape)
display(X_test_cnn.shape)
# Out:
# (289885, 187, 1)
# (17511, 187, 1)
# (21892, 187, 1)

# %%
# Input layer
input_layer = Input(shape=(187, 1))

# Initial convolution
conv_0 = Conv1D(filters=32, kernel_size=5, padding='same')(input_layer)

# Residual Block 1
x = BatchNormalization()(conv_0)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = Add()([conv_0, x])
x = ReLU()(x)
x = MaxPooling1D(pool_size=5, strides=2, padding='same')(x)
x = Dropout(0.1)(x)

# Residual Block 2
shortcut = x
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = Add()([shortcut, x])
x = ReLU()(x)
x = MaxPooling1D(pool_size=5, strides=2, padding='same')(x)
x = Dropout(0.1)(x)

# Residual Block 3
shortcut = x
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = Add()([shortcut, x])
x = ReLU()(x)
x = MaxPooling1D(pool_size=5, strides=2, padding='same')(x)
x = Dropout(0.2)(x)

# Residual Block 4
shortcut = x
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = Add()([shortcut, x])
x = ReLU()(x)
x = MaxPooling1D(pool_size=5, strides=2, padding='same')(x)
x = Dropout(0.3)(x)

# Residual Block 5
shortcut = x
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = ReLU()(x)
x = Conv1D(32, 5, padding='same')(x)
x = BatchNormalization()(x)
x = Add()([shortcut, x])
x = ReLU()(x)
x = MaxPooling1D(pool_size=5, strides=2, padding='same')(x)
x = Dropout(0.3)(x)

# Fully connected layers
x = Flatten()(x)
x = Dense(32, activation='relu')(x)
x = Dropout(0.3)(x) 
output_layer = Dense(5, activation='softmax')(x)

# Model
cnn = Model(inputs=input_layer, outputs=output_layer)

# Summary
cnn.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 187, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 187, 32)   │        192 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 187, 32)   │        128 │ conv1d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 187, 32)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 187, 32)   │      5,152 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 187, 32)   │        128 │ conv1d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 187, 32)   │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 187, 32)   │      5,152 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 187, 32)   │        128 │ conv1d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 187, 32)   │          0 │ conv1d[0][0],     │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 187, 32)   │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 94, 32)    │          0 │ re_lu_2[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 94, 32)    │          0 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 94, 32)    │        128 │ dropout[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 94, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 94, 32)    │      5,152 │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 94, 32)    │        128 │ conv1d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 94, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 94, 32)    │      5,152 │ re_lu_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 94, 32)    │        128 │ conv1d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 94, 32)    │          0 │ dropout[0][0],    │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 94, 32)    │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 47, 32)    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 47, 32)    │          0 │ max_pooling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 47, 32)    │        128 │ dropout_1[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 47, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 47, 32)    │      5,152 │ re_lu_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 47, 32)    │        128 │ conv1d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 47, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 47, 32)    │      5,152 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 47, 32)    │        128 │ conv1d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 47, 32)    │          0 │ dropout_1[0][0],  │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 47, 32)    │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 24, 32)    │          0 │ re_lu_8[0][0]     │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 24, 32)    │          0 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32)    │        128 │ dropout_2[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 24, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 24, 32)    │      5,152 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32)    │        128 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 24, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 24, 32)    │      5,152 │ re_lu_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32)    │        128 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 24, 32)    │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 24, 32)    │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_3     │ (None, 12, 32)    │          0 │ re_lu_11[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 12, 32)    │          0 │ max_pooling1d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 32)    │        128 │ dropout_3[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 12, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 12, 32)    │      5,152 │ re_lu_12[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 32)    │        128 │ conv1d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 12, 32)    │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 12, 32)    │      5,152 │ re_lu_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 32)    │        128 │ conv1d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 12, 32)    │          0 │ dropout_3[0][0],  │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 12, 32)    │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_4     │ (None, 6, 32)     │          0 │ re_lu_14[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 6, 32)     │          0 │ max_pooling1d_4[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 192)       │          0 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │      6,176 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5)         │        165 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 59,973 (234.27 KB)
#  Trainable params: 59,013 (230.52 KB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Learning rate with exponential decay
initial_learning_rate = 0.001
lr_schedule = ExponentialDecay(
    initial_learning_rate,
    decay_steps=10000,
    decay_rate=0.75,
    staircase=True
)

# Adam optimizer with specified hyperparameters
optimizer = Adam(
    learning_rate=lr_schedule,
    beta_1=0.9,
    beta_2=0.999
)


# Compile the model
cnn.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy']
)

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=8,
    min_delta=1e-4,
    restore_best_weights=True,
    verbose=1
)

# Define where and how to save the best model
checkpoint = ModelCheckpoint(
    filepath=OUTPUT_PATH+model_name+'_bs_epoch_{epoch:02d}_valloss_{val_loss:.4f}.keras',   # file path (can be .keras or .h5)
    monitor='val_loss',        # metric to monitor
    mode='min',                    # because higher accuracy is better
    save_best_only=True,           # only save when val_accuracy improves
    verbose=1                      # print message when a model is saved
)

# %%
history = cnn.fit(
    X_train_sm_cnn,
    y_train_sm,
    epochs=EPOCHS,
    batch_size=128,
    validation_data=(X_val_cnn, y_val),  
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6639 - loss: 1.2976
# Epoch 1: val_loss improved from None to 1.07010, saving model to src/models/CNN/cnn8_sm_bs_epoch_01_valloss_1.0701.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 109s 45ms/step - accuracy: 0.7970 - loss: 0.6144 - val_accuracy: 0.5114 - val_loss: 1.0701
# Epoch 2/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9263 - loss: 0.2232
# Epoch 2: val_loss improved from 1.07010 to 0.75944, saving model to src/models/CNN/cnn8_sm_bs_epoch_02_valloss_0.7594.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 101s 44ms/step - accuracy: 0.9367 - loss: 0.1945 - val_accuracy: 0.6734 - val_loss: 0.7594
# Epoch 3/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9559 - loss: 0.1376
# Epoch 3: val_loss improved from 0.75944 to 0.64795, saving model to src/models/CNN/cnn8_sm_bs_epoch_03_valloss_0.6480.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9592 - loss: 0.1278 - val_accuracy: 0.7100 - val_loss: 0.6480
# Epoch 4/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9664 - loss: 0.1038
# Epoch 4: val_loss improved from 0.64795 to 0.48661, saving model to src/models/CNN/cnn8_sm_bs_epoch_04_valloss_0.4866.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 104s 46ms/step - accuracy: 0.9680 - loss: 0.0991 - val_accuracy: 0.7842 - val_loss: 0.4866
# Epoch 5/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9739 - loss: 0.0842
# Epoch 5: val_loss improved from 0.48661 to 0.43245, saving model to src/models/CNN/cnn8_sm_bs_epoch_05_valloss_0.4325.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 110s 48ms/step - accuracy: 0.9754 - loss: 0.0791 - val_accuracy: 0.8222 - val_loss: 0.4325
# Epoch 6/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9784 - loss: 0.0684
# Epoch 6: val_loss improved from 0.43245 to 0.28186, saving model to src/models/CNN/cnn8_sm_bs_epoch_06_valloss_0.2819.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 121s 54ms/step - accuracy: 0.9792 - loss: 0.0654 - val_accuracy: 0.8924 - val_loss: 0.2819
# Epoch 7/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9805 - loss: 0.0614
# Epoch 7: val_loss did not improve from 0.28186
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 129s 57ms/step - accuracy: 0.9809 - loss: 0.0604 - val_accuracy: 0.8447 - val_loss: 0.3674
# Epoch 8/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9825 - loss: 0.0552
# Epoch 8: val_loss improved from 0.28186 to 0.27233, saving model to src/models/CNN/cnn8_sm_bs_epoch_08_valloss_0.2723.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 112s 50ms/step - accuracy: 0.9826 - loss: 0.0548 - val_accuracy: 0.8896 - val_loss: 0.2723
# Epoch 9/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9839 - loss: 0.0523
# Epoch 9: val_loss improved from 0.27233 to 0.26638, saving model to src/models/CNN/cnn8_sm_bs_epoch_09_valloss_0.2664.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 110s 49ms/step - accuracy: 0.9841 - loss: 0.0511 - val_accuracy: 0.8917 - val_loss: 0.2664
# Epoch 10/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9869 - loss: 0.0430
# Epoch 10: val_loss improved from 0.26638 to 0.19700, saving model to src/models/CNN/cnn8_sm_bs_epoch_10_valloss_0.1970.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 111s 49ms/step - accuracy: 0.9866 - loss: 0.0429 - val_accuracy: 0.9222 - val_loss: 0.1970
# Epoch 11/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9875 - loss: 0.0399
# Epoch 11: val_loss improved from 0.19700 to 0.17284, saving model to src/models/CNN/cnn8_sm_bs_epoch_11_valloss_0.1728.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 110s 49ms/step - accuracy: 0.9873 - loss: 0.0402 - val_accuracy: 0.9360 - val_loss: 0.1728
# Epoch 12/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9874 - loss: 0.0397
# Epoch 12: val_loss did not improve from 0.17284
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 111s 49ms/step - accuracy: 0.9878 - loss: 0.0390 - val_accuracy: 0.8945 - val_loss: 0.2916
# Epoch 13/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9881 - loss: 0.0382
# Epoch 13: val_loss did not improve from 0.17284
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 111s 49ms/step - accuracy: 0.9883 - loss: 0.0368 - val_accuracy: 0.9211 - val_loss: 0.2095
# Epoch 14/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9890 - loss: 0.0336
# Epoch 14: val_loss did not improve from 0.17284
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 161s 71ms/step - accuracy: 0.9895 - loss: 0.0325 - val_accuracy: 0.9292 - val_loss: 0.1883
# Epoch 15/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9903 - loss: 0.0312
# Epoch 15: val_loss did not improve from 0.17284
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 196s 86ms/step - accuracy: 0.9903 - loss: 0.0310 - val_accuracy: 0.9299 - val_loss: 0.1960
# Epoch 16/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9909 - loss: 0.0289
# Epoch 16: val_loss did not improve from 0.17284
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 157s 69ms/step - accuracy: 0.9909 - loss: 0.0289 - val_accuracy: 0.9307 - val_loss: 0.1940
# Epoch 17/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9915 - loss: 0.0280
# Epoch 17: val_loss did not improve from 0.17284
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 135s 59ms/step - accuracy: 0.9914 - loss: 0.0281 - val_accuracy: 0.9222 - val_loss: 0.2087
# Epoch 18/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9919 - loss: 0.0258
# Epoch 18: val_loss improved from 0.17284 to 0.14925, saving model to src/models/CNN/cnn8_sm_bs_epoch_18_valloss_0.1493.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 180s 79ms/step - accuracy: 0.9916 - loss: 0.0267 - val_accuracy: 0.9492 - val_loss: 0.1493
# Epoch 19/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9927 - loss: 0.0232
# Epoch 19: val_loss improved from 0.14925 to 0.11068, saving model to src/models/CNN/cnn8_sm_bs_epoch_19_valloss_0.1107.keras
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 179s 79ms/step - accuracy: 0.9927 - loss: 0.0233 - val_accuracy: 0.9632 - val_loss: 0.1107
# Epoch 20/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9928 - loss: 0.0238
# Epoch 20: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 174s 77ms/step - accuracy: 0.9928 - loss: 0.0235 - val_accuracy: 0.9560 - val_loss: 0.1306
# Epoch 21/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9930 - loss: 0.0225
# Epoch 21: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 175s 77ms/step - accuracy: 0.9929 - loss: 0.0224 - val_accuracy: 0.9604 - val_loss: 0.1238
# Epoch 22/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9932 - loss: 0.0227
# Epoch 22: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 173s 76ms/step - accuracy: 0.9931 - loss: 0.0230 - val_accuracy: 0.9597 - val_loss: 0.1185
# Epoch 23/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9937 - loss: 0.0206
# Epoch 23: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 115s 51ms/step - accuracy: 0.9939 - loss: 0.0199 - val_accuracy: 0.9615 - val_loss: 0.1207
# Epoch 24/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9937 - loss: 0.0201
# Epoch 24: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 101s 45ms/step - accuracy: 0.9938 - loss: 0.0199 - val_accuracy: 0.9506 - val_loss: 0.1367
# Epoch 25/50
# 2264/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9940 - loss: 0.0199
# Epoch 25: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 101s 44ms/step - accuracy: 0.9941 - loss: 0.0192 - val_accuracy: 0.9501 - val_loss: 0.1434
# Epoch 26/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9942 - loss: 0.0186
# Epoch 26: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 101s 45ms/step - accuracy: 0.9943 - loss: 0.0185 - val_accuracy: 0.9590 - val_loss: 0.1126
# Epoch 27/50
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9946 - loss: 0.0178
# Epoch 27: val_loss did not improve from 0.11068
# 2265/2265 ━━━━━━━━━━━━━━━━━━━━ 101s 45ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.9607 - val_loss: 0.1187
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %%
def parse_epoch_from_name(name, default_epochs=EPOCHS):
    # Expect pattern like ..._epoch_12_...; returns int if found else default
    m = re.search(r"epoch_(\d+)", name)
    return int(m.group(1)) if m else default_epochs

def parse_val_loss_from_name(name):
    # Expect pattern like ..._valloss_0.1234.keras
    m = re.search(r"valloss_([0-9]+\.[0-9]+)", name)
    return float(m.group(1)) if m else np.nan

# Safer file filtering
model_dir = Path(OUTPUT_PATH)
model_paths = sorted([p for p in model_dir.glob("*.keras")])
model_paths = [p for p in model_paths if model_name in model_paths]

all_labels = np.unique(y_test)  # ground-truth labels present in test set
rows = []

print(all_labels)

for p in model_paths:
    print(p)
    model_ = load_model(str(p))

    y_pred = model_.predict(X_test_cnn)
    y_pred_class = np.argmax(y_pred, axis=1)

    # Force consistent label space for metrics
    print(classification_report(y_test, y_pred_class, digits=4))
    report = classification_report(
        y_test, y_pred_class, labels=all_labels, output_dict=True, zero_division=0
    )

    print(pd.crosstab(y_test, y_pred_class, colnames=['Predictions']))

    accuracy = accuracy_score(y_test, y_pred_class)
    epoch_num = parse_epoch_from_name(p.name)
    val_loss = parse_val_loss_from_name(p.name)

    row = {
        "sampling_method": SAMPLING_METHOD,
        "outliers_removed": REMOVE_OUTLIERS,
        "epochs": epoch_num,
        "model": p.name,
        "val_loss": round(float(val_loss), 4) if not np.isnan(val_loss) else np.nan,
        "test_accuracy": round(float(accuracy), 4),
        "test_f1_macro": round(float(report["macro avg"]["f1-score"]), 4),
        "test_precision_macro": round(float(report["macro avg"]["precision"]), 4),
        "test_recall_macro": round(float(report["macro avg"]["recall"]), 4),
        "test_f1_weighted": round(float(report["weighted avg"]["f1-score"]), 4),
        "test_precision_weighted": round(float(report["weighted avg"]["precision"]), 4),
        "test_recall_weighted": round(float(report["weighted avg"]["recall"]), 4),
    }
    for lbl in all_labels:
        row[f"test_f1_cls_{int(lbl)}"] = round(float(report[str(lbl)]["f1-score"]), 4)
        row[f"test_precision_cls_{int(lbl)}"1] = round(float(report[str(lbl)]["precision"]), 4)
        row[f"test_recall_cls_{int(lbl)}"] = round(float(report[str(lbl)]["recall"]), 4)
        row[f"test_support_cls_{int(lbl)}"] = int(report[str(lbl)]["support"])

    rows.append(row)

df = pd.DataFrame(rows)
os.makedirs(os.path.dirname(results_csv), exist_ok=True)
if os.path.exists(results_csv):
    df.to_csv(results_csv, mode='a', index=False, header=False)
else:
    df.to_csv(results_csv, index=False)
# Out:
#   Cell In[8], line 56
#     row[f"test_precision_cls_{int(lbl)}"1] = round(float(report[str(lbl)]["precision"]), 4)
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
plot_training_history(history, "reports/figures/training_history/", model_name)
